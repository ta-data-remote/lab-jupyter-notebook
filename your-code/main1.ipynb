# %% [markdown]
# # 1.0 This is my favorite holiday destination

# %% [markdown]
# ##**The Alpes**

# %% [markdown]
# ![zugspitze.jpg](attachment:zugspitze.jpg)

# %% [markdown]
# Reasons to climb the Zugspitze:
#
# -*That is what it feels like to have Germany at your feet: At precisely 2,962 metres above sea level, the Zugspitze is the highest mountain in the country and home to three glaciers*
#
# -*Three toboggan runs, Germany’s highest church, an igloo village and excellent mountain restaurants are reason enough for smiling faces*
#
# -*Fresh air to re-energise from a stressful Ironhack week*

# %% [markdown]
# # 2.0 Further information can be found here
#
#  [external link](https://www.youtube.com/watch?v=IXnf0uSVpKce)
